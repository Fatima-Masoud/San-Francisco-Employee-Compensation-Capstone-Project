# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Employee_Compensation_Accurate.csv")

# 1️⃣ Missing values
print("Missing values:\n", df.isna().sum())

# 2️⃣ Negative and infinite values
num_cols = df.select_dtypes(include=[np.number]).columns
print("\nNegative values:\n", (df[num_cols] < 0).sum())
print("\nInfinite values:\n", np.isinf(df[num_cols]).sum())

# 3️⃣ Descriptive summary
print("\nStatistical summary:\n", df.describe())

# 4️⃣ Text columns: duplicates and consistency
text_cols = df.select_dtypes(include='object').columns
for col in text_cols:
    print(f"\n{col} → {df[col].nunique()} unique values")
    print(df[col].unique()[:10])  # check first 10 unique values
# Out:
# Missing values:
#  Year                      0
# Organization_Group        0
# Department                0
# Job_Family                0
# Job                       0
# Employment_Type           0
# Salaries                  0
# Overtime                  0
# Other_Salaries            0
# Total_Salary              0
# Retirement                0
# Health_and_Dental         0
# Other_Benefits            0
# Total_Benefits            0
# Total_Compensation        0
# Union                     0
# Total_Pay                 0
# Pay_to_Benefit_Ratio    116
# Overtime_Ratio            0
# Benefits_Percentage       0
# Overtime_Percentage       0
# dtype: int64
#
# Negative values:
#  Year                      0
# Salaries                  0
# Overtime                  0
# Other_Salaries          128
# Total_Salary              0
# Retirement                0
# Health_and_Dental         0
# Other_Benefits          490
# Total_Benefits            0
# Total_Compensation        0
# Total_Pay                 0
# Pay_to_Benefit_Ratio      0
# Overtime_Ratio            0
# Benefits_Percentage       0
# Overtime_Percentage       0
# dtype: int64
#
# Infinite values:
#  Year                    0
# Salaries                0
# Overtime                0
# Other_Salaries          0
# Total_Salary            0
# Retirement              0
# Health_and_Dental       0
# Other_Benefits          0
# Total_Benefits          0
# Total_Compensation      0
# Total_Pay               0
# Pay_to_Benefit_Ratio    0
# Overtime_Ratio          0
# Benefits_Percentage     0
# Overtime_Percentage     0
# dtype: int64
#
# Statistical summary:
#                 Year      Salaries      Overtime  Other_Salaries  Total_Salary  \
# count  1.036789e+06  1.036789e+06  1.036789e+06    1.036789e+06  1.036789e+06
# mean   2.018775e+03  8.082167e+04  7.198758e+03    4.200953e+03  9.222138e+04
# std    3.604904e+00  5.338407e+04  1.808122e+04    8.326756e+03  6.431385e+04
# min    2.013000e+03  1.000000e-01  0.000000e+00   -1.913110e+04  1.100000e-01
# 25%    2.016000e+03  4.161203e+04  0.000000e+00    0.000000e+00  4.548339e+04
# 50%    2.019000e+03  7.801975e+04  0.000000e+00    8.973900e+02  8.632040e+04
# 75%    2.022000e+03  1.140892e+05  5.837370e+03    4.944490e+03  1.287174e+05
# max    2.025000e+03  6.519367e+05  4.562011e+05    3.428026e+05  7.221863e+05
#
#          Retirement  Health_and_Dental  Other_Benefits  Total_Benefits  \
# count  1.036789e+06       1.036789e+06    1.036789e+06    1.036789e+06
# mean   1.566171e+04       1.100999e+04    5.740210e+03    3.241191e+04
# std    1.172277e+04       6.812032e+03    3.941833e+03    1.975662e+04
# min    0.000000e+00       0.000000e+00   -1.063650e+04    0.000000e+00
# 25%    7.121880e+03       4.681300e+03    2.360200e+03    1.683867e+04
# 50%    1.548101e+04       1.296822e+04    5.603540e+03    3.561321e+04
# 75%    2.215844e+04       1.595910e+04    8.516410e+03    4.497611e+04
# max    1.964351e+05       5.940523e+04    3.569104e+04    2.250063e+05
#
#        Total_Compensation     Total_Pay  Pay_to_Benefit_Ratio  Overtime_Ratio  \
# count        1.036789e+06  1.036789e+06          1.036673e+06    1.036789e+06
# mean         1.246333e+05  9.222138e+04          7.682051e+00    5.381948e-02
# std          8.205022e+04  6.431385e+04          9.263888e+02    9.455735e-02
# min          1.200000e-01  1.100000e-01          1.000000e-02    0.000000e+00
# 25%          6.344406e+04  4.548339e+04          2.240000e+00    0.000000e+00
# 50%          1.220249e+05  8.632040e+04          2.610000e+00    0.000000e+00
# 75%          1.741138e+05  1.287174e+05          3.480000e+00    7.098116e-02
# max          8.687280e+05  7.221863e+05          4.406448e+05    9.944382e-01
#
#        Benefits_Percentage  Overtime_Percentage
# count         1.036789e+06         1.036789e+06
# mean          2.597940e+01         4.116060e+00
# std           7.974238e+00         7.492756e+00
# min           0.000000e+00         0.000000e+00
# 25%           2.233000e+01         0.000000e+00
# 50%           2.774000e+01         0.000000e+00
# 75%           3.091000e+01         5.170000e+00
# max           9.950000e+01         9.165000e+01
#
# Organization_Group → 7 unique values
# ['Public Works, Transportation & Commerce' 'Culture & Recreation'
#  'General Administration & Finance'
#  'Human Welfare & Neighborhood Development' 'Public Protection'
#  'Community Health' 'General City Responsibilities']
#
# Department → 125 unique values
# ['Pub Public Utilities Bureaus' 'Rec Recreation & Park Commsn'
#  'Dpw Gsa - Public Works' 'Prt Port' 'Adm Gen Svcs Agency-City Admin'
#  'Mta Municipal Transprtn Agncy' 'Hsa Human Services Agency'
#  'Juv Juvenile Probation' 'Fir Fire Department' 'Dph Public Health']
#
# Job_Family → 59 unique values
# ['Professional Engineering' 'Public Service Aide'
#  'Supervisory-Labor & Trade' 'Pub Relations & Spec Assts'
#  'Journeyman Trade' 'Human Services' 'Correction & Detention'
#  'Fire Services' 'Nursing' 'Med Therapy & Auxiliary']
#
# Job → 1351 unique values
# ['Planner 3-Environmental Review' 'Public Service Trainee' 'Engineer'
#  'Pile Worker' 'Customer Service Agent' 'Electrical Transit System Mech'
#  'Eligibility Worker Supervisor' 'Counselor, Juvenile Hall Sfers'
#  'Captain, Fire Suppression' 'Nurse Manager']
#
# Employment_Type → 7 unique values
# ['Not Specified' 'Permanent Civil Service' 'Temporary Exempt'
#  'Permanent Exempt' 'Other' 'Temporary Provisional'
#  'Temporary Civil Service']
#
# Union → 130 unique values
# ['Prof & Tech Engineers - Miscellaneous, Local 21'
#  'SEIU - Miscellaneous, Local 1021' 'Pile Drivers, Local 34'
#  'Electrical Workers, Local 6' 'SEIU - Human Services, Local 1021'
#  'Firefighters - Miscellaneous, Local 798'
#  'Teamsters - Supervising Nurses, Local 856'
#  'SEIU - Staff and Per Diem Nurses, Local 1021'
#  'Transport Workers - Transit Operators, Local 250-A'
#  "Municipal Attorneys' Association"]

# %%
df["Other_Salaries"] = df["Other_Salaries"].abs()
df["Other_Benefits"] = df["Other_Benefits"].abs()

# %%
df["Pay_to_Benefit_Ratio"] = df["Pay_to_Benefit_Ratio"].replace([np.inf, -np.inf], np.nan)

df["Pay_to_Benefit_Ratio"] = df["Pay_to_Benefit_Ratio"].fillna(df["Pay_to_Benefit_Ratio"].median())

# %%
num_cols = [
    "Salaries","Overtime","Other_Salaries","Total_Salary",
    "Retirement","Health_and_Dental","Other_Benefits",
    "Total_Benefits","Total_Compensation"
]
df[num_cols] = df[num_cols].apply(pd.to_numeric, errors="coerce")

# %%
df.to_csv("Employee_Compensation_Final_For_Tableau.csv", index=False)
