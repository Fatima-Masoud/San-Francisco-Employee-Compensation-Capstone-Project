# %%
import pandas as pd

# %%
df = pd.read_csv("Employee_Compensation_Final.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1037296 entries, 0 to 1037295
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   Year                  1037296 non-null  int64
#  1   Organization_Group    1037296 non-null  object
#  2   Department            1037296 non-null  object
#  3   Job_Family            1037296 non-null  object
#  4   Job                   1037296 non-null  object
#  5   Employment_Type       1037296 non-null  object
#  6   Salaries              1037296 non-null  float64
#  7   Overtime              1037296 non-null  float64
#  8   Other_Salaries        1037296 non-null  float64
#  9   Total_Salary          1037296 non-null  float64
#  10  Retirement            1037296 non-null  float64
#  11  Health_and_Dental     1037296 non-null  float64
#  12  Other_Benefits        1037296 non-null  float64
#  13  Total_Benefits        1037296 non-null  float64
# ...

# %%
print(df.head())
# Out:
#    Year                       Organization_Group  \
# 0  2016  Public Works, Transportation & Commerce
# 1  2013                     Culture & Recreation
# 2  2013  Public Works, Transportation & Commerce
# 3  2015  Public Works, Transportation & Commerce
# 4  2015         General Administration & Finance
#
#                        Department                  Job_Family  \
# 0    Pub Public Utilities Bureaus    Professional Engineering
# 1    Rec Recreation & Park Commsn         Public Service Aide
# 2          Dpw Gsa - Public Works    Professional Engineering
# 3                        Prt Port   Supervisory-Labor & Trade
# 4  Adm Gen Svcs Agency-City Admin  Pub Relations & Spec Assts
#
#                               Job Employment_Type   Salaries  Overtime  \
# 0  Planner 3-Environmental Review   Not Specified   54444.00      0.00
# 1          Public Service Trainee   Not Specified    1864.73      0.00
# 2                        Engineer   Not Specified  126932.10      0.00
# ...

# %%
print(df.describe())
# Out:
#                Year      Salaries      Overtime  Other_Salaries  Total_Salary  \
# count  1.037296e+06  1.037296e+06  1.037296e+06    1.037296e+06  1.037296e+06
# mean   2.018774e+03  8.079405e+04  7.195164e+03    4.200273e+03  9.218949e+04
# std    3.605499e+00  5.339539e+04  1.807768e+04    8.327143e+03  6.432305e+04
# min    2.013000e+03  1.000000e-01 -4.711391e+04   -1.913110e+04  1.100000e-01
# 25%    2.016000e+03  4.154171e+04  0.000000e+00    0.000000e+00  4.539371e+04
# 50%    2.019000e+03  7.800679e+04  0.000000e+00    8.961550e+02  8.629136e+04
# 75%    2.022000e+03  1.140711e+05  5.830792e+03    4.942670e+03  1.286994e+05
# max    2.025000e+03  6.519367e+05  4.562011e+05    3.428026e+05  7.221863e+05
#
#          Retirement  Health_and_Dental  Other_Benefits  Total_Benefits  \
# count  1.037296e+06       1.037296e+06    1.037296e+06    1.037296e+06
# mean   1.565469e+04       1.100534e+04    5.738398e+03    3.239843e+04
# ...
